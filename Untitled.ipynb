# %%
print('hi')
# Out:
# hi

# %%
%1s
# Out:
# UsageError: Line magic function `%1s` not found.

# %%
type(3)
# Out:
# int

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_61/1822790664.py in <module>
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %%
type('true')
# Out:
# str

# %%
import math

# %%
x = 'name'

# %%
x
# Out:
# 'name'

# %%
print(x)
# Out:
# name

# %%
y= 'name2'

# %%
z= z + y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_61/1431860170.py in <module>
# ----> 1 z= z + y
#
# NameError: name 'z' is not defined

# %%
z = x + y

# %%
z
# Out:
# 'namename2'

# %%
z = 'tecnologico'
z.find ('cn')
# Out:
# 2

# %%
aList = [2 ,3.0, 'name', True, None]
aList
# Out:
# [2, 3.0, 'name', True, None]

# %%
type(aList)
# Out:
# list

# %%
print(aList)
# Out:
# [2, 3.0, 'name', True, None]

# %%
for i in aList:
    print(i,'\t', type(i))
# Out:
# 2 	 <class 'int'>
# 3.0 	 <class 'float'>
# name 	 <class 'str'>
# True 	 <class 'bool'>
# None 	 <class 'NoneType'>

# %%
a = [1,2,3,4,5]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[4]
# Out:
# 5

# %%
a[-1]
# Out:
# 5

# %%
a[-2:-1]
# Out:
# [4]

# %%
a[-2]
# Out:
# 4

# %%
a[-3:-1]
# Out:
# [3, 4]

# %%
sum(a)
# Out:
# 15

# %%
average = sum(a)/len(a)
average
# Out:
# 3.0

# %%
import numpy as np

# %%
average(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_61/3343761137.py in <module>
# ----> 1 average(a)
#
# TypeError: 'float' object is not callable

# %%
np.average(a)
# Out:
# 3.0

# %%
mean(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_61/3531512137.py in <module>
# ----> 1 mean(a)
#
# NameError: name 'mean' is not defined

# %%
sList = ['a','c','d','b']
sList
# Out:
# ['a', 'c', 'd', 'b']

# %%
sList.sort()

# %%
sList
# Out:
# ['a', 'b', 'c', 'd']

# %%
import pandas as pd

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)

# %%
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
df.tail(2)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
d = df.columns

# %%
d.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_61/575454195.py in <module>
# ----> 1 d.sort()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in sort(self, *args, **kwargs)
#    4259         Use sort_values instead.
#    4260         """
# -> 4261         raise TypeError("cannot sort an Index object in-place, use sort_values instead")
#    4262
#    4263     def shift(self, periods=1, freq=None):
#
# TypeError: cannot sort an Index object in-place, use sort_values instead

# %%
type(d)
# Out:
# pandas.core.indexes.base.Index

# %%
d = df.columns.tolist()
d.sort()

# %%
d
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
int(3.99)

# %%
int(3.99)

# %%
type
